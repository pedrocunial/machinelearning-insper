# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %% [markdown]
# # Classificação de texto

# %% [markdown]
# Vamos começar lendo o dataset "20 newsgroups". Um conjunto de documentos é chamado de **corpus**.

# %%
from sklearn.datasets import fetch_20newsgroups

data = fetch_20newsgroups(subset='train', shuffle=True)
print("{} documents, {} categories".format(len(data.filenames), len(data.target_names)))
# Out:
# 11314 documents, 20 categories

# %%
for k in range(6, 10):
    print(data.target_names[data.target[k]])
    print('-' * 3)
    print(data.data[k])
    print('-' * 15)
# Out:
# sci.med
# ---
# From: bmdelane@quads.uchicago.edu (brian manning delaney)
# Subject: Brain Tumor Treatment (thanks)
# Reply-To: bmdelane@midway.uchicago.edu
# Organization: University of Chicago
# Lines: 12
#
# There were a few people who responded to my request for info on
# treatment for astrocytomas through email, whom I couldn't thank
# directly because of mail-bouncing probs (Sean, Debra, and Sharon).  So
# I thought I'd publicly thank everyone.
#
# Thanks!
#
# (I'm sure glad I accidentally hit "rn" instead of "rm" when I was
# trying to delete a file last September. "Hmmm... 'News?' What's
# this?"....)
#
# -Brian
#
# ---------------
# comp.sys.ibm.pc.hardware
# ---
# From: bgrubb@dante.nmsu.edu (GRUBB)
# Subject: Re: IDE vs SCSI
# Organization: New Mexico State University, Las Cruces, NM
# Lines: 44
# Distribution: world
# NNTP-Posting-Host: dante.nmsu.edu
#
# DXB132@psuvm.psu.edu writes:
# >In article <1qlbrlINN7rk@dns1.NMSU.Edu>, bgrubb@dante.nmsu.edu (GRUBB) says:
# >>In PC Magazine April 27, 1993:29 "Although SCSI is twice as fasst as ESDI,
# >>20% faster than IDE, and support up to 7 devices its acceptance ...has
# >>long been stalled by incompatability problems and installation headaches."
#
# >I love it when magazine writers make stupid statements like that re:
# >performance. Where do they get those numbers? I'll list the actual
# >performance ranges, which should convince anyone that such a
# >statement is absurd:
# >SCSI-I ranges from 0-5MB/s.
# >SCSI-II ranges from 0-40MB/s.
# >IDE ranges from 0-8.3MB/s.
# >ESDI is always 1.25MB/s (although there are some non-standard versions)
# ALL this shows is that YOU don't know much about SCSI.
#
# SCSI-1 {with a SCSI-1 controler chip} range is indeed 0-5MB/s
# and that is ALL you have right about SCSI
# SCSI-1 {With a SCSI-2 controller chip}: 4-6MB/s with 10MB/s burst {8-bit}
#  Note the INCREASE in SPEED, the Mac Quadra uses this version of SCSI-1
#  so it DOES exist. Some PC use this set up too.
# SCSI-2 {8-bit/SCSI-1 mode}:          4-6MB/s with 10MB/s burst
# SCSI-2 {16-bit/wide or fast mode}:  8-12MB/s with 20MB/s burst
# SCSI-2 {32-bit/wide AND fast}:     15-20MB/s with 40MB/s burst
#
# By your OWN data the "Although SCSI is twice as fast as ESDI" is correct
# With a SCSI-2 controller chip SCSI-1 can reach 10MB/s which is indeed
# "20% faster than IDE" {120% of 8.3 is 9.96}. ALL these SCSI facts have been
# posted to this newsgroup in my Mac & IBM info sheet {available by FTP on
# sumex-aim.stanford.edu (36.44.0.6) in the info-mac/report as
# mac-ibm-compare[version #].txt (It should be 173 but 161 may still be there)}
#
# Part of this problem is both Mac and IBM PC are inconsiant about what SCSI
# is which.  Though it is WELL documented that the Quadra has a SCSI-2 chip
# an Apple salesperson said "it uses a fast SCSI-1 chip" {Not at a 6MB/s,
# 10MB/s burst it does not. SCSI-1 is 5MB/s maximum synchronous and Quadra
# uses ANsynchronous SCSI which is SLOWER}  It seems that Mac and IBM see
# SCSI-1 interface and think 'SCSI-1' when it maybe a SCSI-1 interface driven
# in the machine by a SCSi-2 controller chip in 8-bit mode {Which is MUCH
# FASTER then true SCSI-1 can go}.
#
# Don't slam an article because you don't understand what is going on.
# One reference for the Quadra's SCSI-2 controller chip is
# (Digital Review, Oct 21, 1991 v8 n33 p8(1)).
#
# ---------------
# comp.os.ms-windows.misc
# ---
# From: holmes7000@iscsvax.uni.edu
# Subject: WIn 3.0 ICON HELP PLEASE!
# Organization: University of Northern Iowa
# Lines: 10
#
# I have win 3.0 and downloaded several icons and BMP's but I can't figure out
# how to change the "wallpaper" or use the icons.  Any help would be appreciated.
#
#
# Thanx,
#
# -Brando
#
# PS Please E-mail me
#
#
# ---------------
# comp.sys.mac.hardware
# ---
# From: kerr@ux1.cso.uiuc.edu (Stan Kerr)
# Subject: Re: Sigma Designs Double up??
# Article-I.D.: ux1.C52u8x.B62
# Organization: University of Illinois at Urbana
# Lines: 29
#
# jap10@po.CWRU.Edu (Joseph A. Pellettiere) writes:
#
#
# >	I am looking for any information about the Sigma Designs
# >	double up board.  All I can figure out is that it is a
# >	hardware compression board that works with AutoDoubler, but
# >	I am not sure about this.  Also how much would one cost?
#
# I've had the board for over a year, and it does work with Diskdoubler,
# but not with Autodoubler, due to a licensing problem with Stac Technologies,
# the owners of the board's compression technology. (I'm writing this
# from memory; I've lost the reference. Please correct me if I'm wrong.)
#
# Using the board, I've had problems with file icons being lost, but it's
# hard to say whether it's the board's fault or something else; however,
# if I decompress the troubled file and recompress it without the board,
# the icon usually reappears. Because of the above mentioned licensing
# problem, the freeware expansion utility DD Expand will not decompress
# a board-compressed file unless you have the board installed.
#
# Since Stac has its own product now, it seems unlikely that the holes
# in Autodoubler/Diskdoubler related to the board will be fixed.
# Which is sad, and makes me very reluctant to buy Stac's product since
# they're being so stinky. (But hey, that's competition.)
# --
#
# Stan Kerr
# Computing & Communications Services Office, U of Illinois/Urbana
# Phone: 217-333-5217  Email: stankerr@uiuc.edu
#
# ---------------

# %% [markdown]
# Vamos processar os documentos para remover pontuação, espaços em branco, etc.

# %%
import string

def normalize_string(s):
    table_punct = str.maketrans({key: None for key in string.punctuation})
    return s.strip().lower().translate(table_punct)

def process_doc(doc):
    return ' '.join([normalize_string(line) for line in doc.split('\n')])

X = [process_doc(doc) for doc in data.data]
y = data.target

# %% [markdown]
# Vamos agora aplicar um "Vectorizer" para transformar os textos em vetores (esparsos) de *features*:

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X_vec = vectorizer.fit_transform(X)

# %%
X_vec.shape
# Out:
# (11314, 138727)

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# Observe que o resultado da aplicação do vectorizer é uma matriz de 11314 linhas por 138727 colunas. Cada linha é um documento. Cada coluna é uma palavra do vocabulário. Essa matriz é chamada **matriz documento-termo** (*document-term matrix*).
#
# Qual a palavra correspondente a cada coluna? Essa pergunta está normalmente respondida na forma reversa: qual a coluna correspondente a cada palavra? O dicionário {palavra: num_coluna} é chamado de **vocabulário** do corpus.

# %%
vectorizer.vocabulary_
# Out:
# {'from': 53426,
#  'lerxstwamumdedu': 71090,
#  'wheres': 134119,
#  'my': 93613,
#  'thing': 125208,
#  'subject': 121733,
#  'what': 134046,
#  'car': 32625,
#  'is': 64814,
#  'this': 125281,
#  'nntppostinghost': 96170,
#  'rac3wamumdedu': 107784,
#  'organization': 99096,
#  'university': 129438,
#  'of': 98012,
#  'maryland': 78932,
#  'college': 36225,
#  'park': 100723,
#  'lines': 71758,
#  '15': 4594,
#  'was': 133183,
#  'wondering': 135127,
#  'if': 62053,
#  'anyone': 23034,
#  'out': 99456,
#  'there': 125062,
#  'could': 38649,
#  'enlighten': 48253,
#  'me': 82319,
#  'on': 98480,
#  'saw': 113975,
#  'the': 124909,
#  'other': 99366,
#  'day': 41266,
#  'it': 65079,
#  '2door': 10785,
#  'sports': 119741,
#  'looked': 72493,
#  'to': 126160,
#  'be': 27020,
#  'late': 70317,
#  '60s': 14878,
#  'early': 46499,
#  '70s': 15920,
#  'called': 32215,
#  'bricklin': 30021,
#  'doors': 45058,
#  'were': 133850,
#  'really': 108803,
#  'small': 118105,
#  'in': 62770,
#  'addition': 20024,
#  'front': 53439,
#  'bumper': 30728,
#  'separate': 115677,
#  'rest': 110659,
#  'body': 29058,
#  'all': 21397,
#  'know': 68998,
#  'can': 32365,
#  'tellme': 124407,
#  'model': 87830,
#  'name': 94398,
#  'engine': 48176,
#  'specs': 119366,
#  'years': 137661,
#  'production': 105517,
#  'where': 134108,
#  'made': 77630,
#  'history': 59952,
#  'or': 98969,
#  'whatever': 134053,
#  'info': 63343,
#  'you': 137927,
#  'have': 58656,
#  'funky': 53904,
#  'looking': 72498,
#  'please': 103399,
#  'email': 47663,
#  'thanks': 124868,
#  'il': 62259,
#  'brought': 30245,
#  'by': 31096,
#  'your': 137969,
#  'neighborhood': 95036,
#  'lerxst': 71089,
#  'guykuocarsonuwashingtonedu': 57544,
#  'guy': 57533,
#  'kuo': 69614,
#  'si': 116986,
#  'clock': 35602,
#  'poll': 103847,
#  'final': 51632,
#  'call': 32201,
#  'summary': 122157,
#  'for': 52593,
#  'reports': 110283,
#  'keywords': 68319,
#  'siaccelerationclockupgrade': 116990,
#  'articleid': 24320,
#  'shelley1qvfo9innc3s': 116441,
#  'washington': 133198,
#  '11': 2567,
#  'carsonuwashingtonedu': 32886,
#  'fair': 50519,
#  'number': 97331,
#  'brave': 29827,
#  'souls': 118972,
#  'who': 134259,
#  'upgraded': 129944,
#  'their': 124952,
#  'oscillator': 99262,
#  'shared': 116269,
#  'experiences': 49889,
#  'send': 115582,
#  'brief': 30041,
#  'message': 83158,
#  'detailing': 42826,
#  'with': 134882,
#  'procedure': 105436,
#  'top': 126463,
#  'speed': 119413,
#  'attained': 25054,
#  'cpu': 38979,
#  'rated': 108349,
#  'add': 20002,
#  'cards': 32709,
#  'and': 22340,
#  'adapters': 19973,
#  'heat': 58945,
#  'sinks': 117461,
#  'hour': 60788,
#  'usage': 130130,
#  'per': 101764,
#  'floppy': 52229,
#  'disk': 44018,
#  'functionality': 53862,
#  '800': 16714,
#  '14': 4172,
#  'floppies': 52227,
#  'are': 23886,
#  'especially': 48987,
#  'requested': 110382,
#  'will': 134487,
#  'summarizing': 122156,
#  'next': 95624,
#  'two': 128123,
#  'days': 41285,
#  'so': 118459,
#  'network': 95309,
#  'knowledge': 69017,
#  'base': 26647,
#  'done': 44989,
#  'upgrade': 129941,
#  'havent': 58663,
#  'answered': 22734,
#  'guykuouwashingtonedu': 57545,
#  'twillisececnpurdueedu': 128087,
#  'thomas': 125317,
#  'willis': 134526,
#  'pb': 101217,
#  'questions': 107509,
#  'purdue': 106876,
#  'engineering': 48180,
#  'computer': 37065,
#  'distribution': 44316,
#  'usa': 130122,
#  '36': 11864,
#  'well': 133739,
#  'folks': 52471,
#  'mac': 77377,
#  'plus': 103530,
#  'finally': 51638,
#  'gave': 54629,
#  'up': 129909,
#  'ghost': 55310,
#  'weekend': 133630,
#  'after': 20565,
#  'starting': 120470,
#  'life': 71503,
#  'as': 24371,
#  '512k': 13976,
#  'way': 133323,
#  'back': 25959,
#  '1985': 6250,
#  'sooo': 118880,
#  'im': 62360,
#  'market': 78700,
#  'new': 95418,
#  'machine': 77450,
#  'bit': 28364,
#  'sooner': 118877,
#  'than': 124855,
#  'intended': 64028,
#  'into': 64350,
#  'picking': 102743,
#  'powerbook': 104402,
#  '160': 4963,
#  'maybe': 80573,
#  '180': 5538,
#  'bunch': 30738,
#  'that': 124885,
#  'hopefully': 60582,
#  'somebody': 118787,
#  'answer': 22731,
#  'does': 44825,
#  'anybody': 23018,
#  'any': 23015,
#  'dirt': 43723,
#  'when': 134102,
#  'round': 112404,
#  'introductions': 64409,
#  'expected': 49850,
#  'id': 61908,
#  'heard': 58914,
#  '185c': 5799,
#  'supposed': 122517,
#  'make': 78050,
#  'an': 22213,
#  'appearence': 23263,
#  'summer': 122159,
#  'but': 30955,
#  'anymore': 23032,
#  'since': 117375,
#  'dont': 45029,
#  'access': 19503,
#  'macleak': 77526,
#  'had': 57791,
#  'more': 88473,
#  'has': 58532,
#  'rumors': 112839,
#  'about': 19285,
#  'price': 105133,
#  'drops': 45672,
#  'line': 71724,
#  'like': 71603,
#  'ones': 98556,
#  'duos': 46120,
#  'just': 67208,
#  'went': 133844,
#  'through': 125520,
#  'recently': 109012,
#  'whats': 134061,
#  'impression': 62716,
#  'display': 44141,
#  'probably': 105381,
#  'swing': 122955,
#  'got': 56215,
#  '80mb': 16963,
#  'rather': 108356,
#  '120': 3140,
#  'feel': 51119,
#  'how': 60845,
#  'much': 91634,
#  'better': 27804,
#  'yea': 137622,
#  'looks': 72504,
#  'great': 56682,
#  'store': 121185,
#  'wow': 135389,
#  'good': 56103,
#  'solicit': 118711,
#  'some': 118785,
#  'opinions': 98817,
#  'people': 101734,
#  'use': 130165,
#  'daytoday': 41291,
#  'its': 65166,
#  'worth': 135347,
#  'taking': 123588,
#  'size': 117595,
#  'money': 88162,
#  'hit': 59958,
#  'get': 55167,
#  'active': 19844,
#  'realize': 108793,
#  'real': 108765,
#  'subjective': 121740,
#  'question': 107491,
#  'ive': 65236,
#  'only': 98600,
#  'played': 103349,
#  'around': 24183,
#  'machines': 77459,
#  'breifly': 29918,
#  'figured': 51523,
#  'actually': 19873,
#  'uses': 130267,
#  'daily': 40673,
#  'might': 84894,
#  'prove': 106018,
#  'helpful': 59193,
#  'hellcats': 59146,
#  'perform': 101820,
#  'advance': 20288,
#  'ill': 62287,
#  'post': 104208,
#  'news': 95483,
#  'reading': 108713,
#  'time': 125805,
#  'at': 24827,
#  'premium': 104883,
#  'finals': 51641,
#  'corner': 38421,
#  'tom': 126292,
#  'twillisecnpurdueedu': 128088,
#  'electrical': 47373,
#  'convictions': 38158,
#  'dangerous': 40822,
#  'enemies': 48111,
#  'truth': 127593,
#  'lies': 71492,
#  'nietzsche': 95860,
#  'jgreenamber': 66132,
#  'joe': 66508,
#  'green': 56716,
#  're': 108661,
#  'weitek': 133712,
#  'p9000': 100155,
#  'harris': 58472,
#  'systems': 123271,
#  'division': 44409,
#  'world': 135286,
#  'amberssdcsdharriscom': 21948,
#  'xnewsreader': 136575,
#  'tin': 125914,
#  'version': 131625,
#  'pl9': 103203,
#  'robert': 111853,
#  'jc': 65738,
#  'kyanko': 69723,
#  'robrjckuucp': 111926,
#  'wrote': 135547,
#  'abraxisiastateedu': 19309,
#  'writes': 135515,
#  'article': 24315,
#  'abraxis734340159class1iastateedu': 19308,
#  'graphics': 56535,
#  'chip': 34547,
#  'far': 50730,
#  'lowlevel': 72758,
#  'stuff': 121592,
#  'goes': 55985,
#  'pretty': 105072,
#  'nice': 95750,
#  'quadrilateral': 107330,
#  'fill': 51588,
#  'command': 36467,
#  'requires': 110401,
#  'four': 52914,
#  'points': 103740,
#  'do': 44678,
#  'weiteks': 133713,
#  'addressphone': 20053,
#  'information': 63411,
#  'corporation': 38454,
#  'jgreencsdharriscom': 66133,
#  'scares': 114148,
#  'person': 102015,
#  'no': 96184,
#  'sense': 115621,
#  'humor': 61249,
#  'jonathan': 66681,
#  'winters': 134782,
#  'jcmheadcfaharvardedu': 65772,
#  'mcdowell': 81462,
#  'shuttle': 116966,
#  'launch': 70392,
#  'smithsonian': 118221,
#  'astrophysical': 24782,
#  'observatory': 97775,
#  'cambridge': 32296,
#  'ma': 77102,
#  'sci': 114459,
#  '23': 9722,
#  'c5owcbn3pworldstdcom': 31717,
#  'tombakerworldstdcom': 126309,
#  'baker': 26198,
#  'c5jlwx4h91cscmuedu': 31582,
#  'etratttacs1ttuedu': 49196,
#  'pack': 100198,
#  'rat': 108338,
#  'clear': 35386,
#  'caution': 33170,
#  'warning': 133124,
#  'memory': 82891,
#  'verify': 131571,
#  'unexpected': 129204,
#  'errors': 48841,
#  'am': 21887,
#  'error': 48837,
#  'sorry': 118940,
#  'dumb': 46070,
#  'parity': 100722,
#  'previously': 105104,
#  'known': 69024,
#  'conditions': 37276,
#  'waivered': 132911,
#  'yes': 137730,
#  'we': 133517,
#  'already': 21654,
#  'knew': 68956,
#  'curious': 40093,
#  'meaning': 82408,
#  'quote': 107625,
#  'understanding': 129094,
#  'basically': 26699,
#  'bugs': 30598,
#  'system': 123240,
#  'software': 118623,
#  'things': 125216,
#  'checked': 34238,
#  'right': 111364,
#  'values': 131024,
#  'yet': 137748,
#  'because': 27142,
#  'they': 125156,
#  'arent': 23910,
#  'set': 115888,
#  'till': 125786,
#  'suchlike': 121972,
#  'fix': 51916,
#  'code': 35998,
#  'possibly': 104205,
#  'introduce': 64403,
#  'tell': 124401,
#  'crew': 39239,
#  'ok': 98245,
#  'see': 115175,
#  '213': 9353,
#  'before': 27246,
#  'liftoff': 71548,
#  'ignore': 62135,
#  'dfovttoulutkovttfi': 43114,
#  'foxvog': 52959,
#  'douglas': 45238,
#  'rewording': 111013,
#  'second': 115068,
#  'amendment': 21991,
#  'ideas': 61940,
#  'vtt': 132608,
#  '58': 14463,
#  '1r1eu14ttransferstratuscom': 8687,
#  'cdtswstratuscom': 33473,
#  'tavares': 123946,
#  '1993apr2008305716899ousrvroulufi': 7270,
#  '1qv87v4j3transferstratuscom': 8622,
#  'c5n3gif8fulowellulowelledu': 31690,
#  'jrutledgcsulowelledu': 66941,
#  'john': 66564,
#  'lawrence': 70479,
#  'rutledge': 112990,
#  'massive': 79030,
#  'destructive': 42809,
#  'power': 104393,
#  'many': 78478,
#  'modern': 87876,
#  'weapons': 133546,
#  'makes': 78065,
#  'cost': 38597,
#  'accidental': 19533,
#  'crimial': 39270,
#  'these': 125121,
#  'mass': 79002,
#  'destruction': 42807,
#  'need': 94946,
#  'control': 38049,
#  'government': 56274,
#  'individual': 63107,
#  'would': 135362,
#  'result': 110717,
#  'needless': 94957,
#  'deaths': 41550,
#  'millions': 85145,
#  'keep': 67941,
#  'bear': 27062,
#  'nonexistant': 96470,
#  'stating': 120550,
#  'youre': 137971,
#  'coming': 36452,
#  'say': 113994,
#  'disagree': 43753,
#  'every': 49416,
#  'count': 38674,
#  'believe': 27405,
#  'individuals': 63114,
#  'should': 116814,
#  'own': 99904,
#  'find': 51660,
#  'hard': 58315,
#  'support': 122495,
#  'neighbors': 95040,
#  'nuclear': 97293,
#  'biological': 28263,
#  'nerve': 95157,
#  'gas': 54523,
#  'hisher': 59917,
#  'property': 105814,
#  'cannot': 32470,
#  'even': 49361,
#  'agree': 20733,
#  'keeping': 67946,
#  'hands': 58194,
#  'hope': 60579,
#  'us': 130101,
#  'sign': 117131,
#  'blank': 28580,
#  'checks': 34260,
#  'course': 38772,
#  'term': 124566,
#  'must': 92221,
#  'rigidly': 111413,
#  'defined': 41976,
#  'bill': 28114,
#  'doug': 45218,
#  'says': 114007,
#  'he': 58829,
#  'means': 82417,
#  'cbw': 33301,
#  'nukes': 97320,
#  'sarah': 113786,
#  'brady': 29723,
#  'she': 116357,
#  'street': 121356,
#  'sweeper': 122897,
#  'shotguns': 116804,
#  'semiautomatic': 115508,
#  'sks': 117759,
#  'rifles': 111350,
#  'doubt': 45203,
#  'using': 130281,
#  'allegedly': 21428,
#  'her': 59316,
#  'then': 124993,
#  'immediately': 62491,
#  'follows': 52488,
#  'thousands': 125418,
#  'killed': 68495,
#  'each': 46451,
#  'year': 137632,
#  'handguns': 58163,
#  'easily': 46557,
#  'reduced': 109355,
#  'putting': 106977,
#  'reasonable': 108863,
#  'restrictions': 110700,
#  'them': 124967,
#  'mean': 82405,
#  'read': 108694,
#  'presenting': 104969,
#  'first': 51806,
#  'argument': 23965,
#  'commonly': 36590,
#  'understood': 129103,
#  'switching': 122984,
#  'topics': 126480,
#  'point': 103719,
#  'evidently': 49448,
#  'show': 116847,
#  'not': 96952,
#  'allowed': 21516,
#  'later': 70326,
#  'analysis': 22266,
#  'given': 55532,
#  'consider': 37647,
#  'another': 22697,
#  'class': 35309,
#  'cdtrocketswstratuscom': 33472,
#  'speak': 119287,
#  'company': 36671,
#  'cdtvosstratuscom': 33474,
#  'write': 135503,
#  'today': 126210,
#  'special': 119312,
#  'investors': 64514,
#  'packet': 100219,
#  'douglasfoxvogvttfi': 45240,
#  'bmdelanequadsuchicagoedu': 28899,
#  'brian': 29982,
#  'manning': 78392,
#  'delaney': 42122,
#  'brain': 29737,
#  'tumor': 127835,
#  'treatment': 127212,
#  'replyto': 110265,
#  'bmdelanemidwayuchicagoedu': 28898,
#  'chicago': 34440,
#  '12': 3139,
#  'few': 51342,
#  'responded': 110623,
#  'request': 110380,
#  'astrocytomas': 24751,
#  'whom': 134283,
#  'couldnt': 38651,
#  'thank': 124862,
#  'directly': 43700,
#  'mailbouncing': 77888,
#  'probs': 105423,
#  'sean': 114971,
#  'debra': 41583,
#  'sharon': 116297,
#  'thought': 125402,
#  'publicly': 106530,
#  'everyone': 49422,
#  'sure': 122565,
#  'glad': 55585,
#  'accidentally': 19534,
#  'rn': 111755,
#  'instead': 63876,
#  'rm': 111721,
#  'trying': 127614,
#  'delete': 42148,
#  'file': 51531,
#  'last': 70291,
#  'september': 115708,
#  'hmmm': 60095,
#  'bgrubbdantenmsuedu': 27886,
#  'grubb': 57045,
#  'ide': 61924,
#  'vs': 132562,
#  'scsi': 114809,
#  'mexico': 83360,
#  'state': 120501,
#  'las': 70260,
#  'cruces': 39504,
#  'nm': 96116,
#  '44': 13008,
#  'dantenmsuedu': 40886,
#  'dxb132psuvmpsuedu': 46298,
#  '1qlbrlinn7rkdns1nmsuedu': 8474,
#  'pc': 101257,
#  'magazine': 77695,
#  'april': 23632,
#  '27': 10373,
#  '199329': 6361,
#  'although': 21765,
#  'twice': 128077,
#  'fasst': 50823,
#  'esdi': 48944,
#  '20': 8850,
#  'faster': 50836,
#  'devices': 43014,
#  'acceptance': 19494,
#  'long': 72430,
#  'been': 27215,
#  'stalled': 120308,
#  'incompatability': 62904,
#  'problems': 105416,
#  'installation': 63852,
#  'headaches': 58835,
#  'love': 72692,
#  'writers': 135514,
#  'stupid': 121621,
#  'statements': 120515,
#  'performance': 101826,
#  'those': 125389,
#  'numbers': 97344,
#  'list': 71897,
#  'actual': 19869,
#  'ranges': 108229,
#  'which': 134137,
#  'convince': 38167,
#  'such': 121970,
#  'statement': 120514,
#  'absurd': 19375,
#  'scsii': 114819,
#  '05mbs': 1183,
#  'scsiii': 114821,
#  '040mbs': 924,
#  '083mbs': 1440,
#  'always': 21877,
#  '125mbs': 3445,
#  'nonstandard': 96724,
#  'versions': 131630,
#  'shows': 116875,
#  'scsi1': 114810,
#  'controler': 38057,
#  'range': 108216,
#  'indeed': 63008,
#  'scsi2': 114813,
#  'controller': 38067,
#  '46mbs': 13238,
#  '10mbs': 2524,
#  'burst': 30878,
#  '8bit': 17547,
#  'note': 96966,
#  'increase': 62961,
#  'quadra': 107320,
#  'exist': 49752,
#  'too': 126414,
#  '8bitscsi1': 17553,
#  'mode': 87827,
#  '16bitwide': 5270,
#  'fast': 50826,
#  '812mbs': 16996,
#  '20mbs': 9208,
#  '32bitwide': 11501,
#  '1520mbs': 4708,
#  '40mbs': 12662,
#  'data': 41025,
#  'correct': 38469,
#  'reach': 108670,
#  '83': 17143,
#  '996': 18659,
#  'facts': 50454,
#  'posted': 104231,
#  'newsgroup': 95556,
#  'ibm': 61742,
#  'sheet': 116394,
#  'available': 25504,
#  'ftp': 53568,
#  'sumexaimstanfordedu': 122141,
#  '364406': 11906,
#  'infomacreport': 63377,
#  'macibmcompareversion': 77485,
#  'txt': 128205,
#  '173': 5393,
#  '161': 5004,
#  'may': 80546,
#  'still': 120993,
#  'part': 100791,
#  'problem': 105400,
#  'both': 29494,
#  'inconsiant': 62928,
#  'though': 125398,
#  'documented': 44749,
#  'apple': 23289,
#  'salesperson': 113496,
#  'said': 113406,
#  '6mbs': 15687,
#  '5mbs': 14644,
#  'maximum': 80498,
#  'synchronous': 123144,
#  'ansynchronous': 22741,
#  'slower': 118050,
#  'seems': 115206,
#  'interface': 64119,
#  'think': 125223,
#  'driven': 45603,
#  'true': 127537,
#  'go': 55884,
#  'slam': 117828,
#  'understand': 129089,
#  'going': 56009,
#  'one': 98508,
#  'reference': 109455,
#  'quadras': 107326,
#  'digital': 43493,
#  'review': 110936,
#  'oct': 97914,
#  '21': 9235,
#  '1991': 6296,
#  'v8': 130883,
#  'n33': 94198,
#  'p81': 100149,
#  'holmes7000iscsvaxuniedu': 60354,
#  'win': 134584,
#  '30': 10979,
#  'icon': 61857,
#  'help': 59186,
#  'northern': 96908,
#  'iowa': 64599,
#  '10': 1783,
#  'downloaded': 45291,
#  'several': 115975,
#  'icons': 61870,
#  'bmps': 28914,
#  'cant': 32495,
#  'figure': 51522,
#  'change': 33993,
#  'wallpaper': 132976,
#  'appreciated': 23393,
#  'thanx': 124880,
#  'brando': 29782,
#  'ps': 106109,
#  'kerrux1csouiucedu': 68151,
#  'stan': 120328,
#  'kerr': 68147,
#  'sigma': 117124,
#  'designs': 42697,
#  'double': 45162,
#  'ux1c52u8xb62': 130699,
#  'illinois': 62313,
#  'urbana': 130045,
#  '29': 10605,
#  'jap10pocwruedu': 65586,
#  'joseph': 66751,
#  'pellettiere': 101600,
#  'board': 28957,
#  'hardware': 58365,
#  'compression': 36964,
#  'works': 135268,
#  'autodoubler': 25397,
#  'also': 21669,
#  'over': 99657,
#  'work': 135235,
#  'diskdoubler': 44023,
#  'due': 46006,
#  'licensing': 71450,
#  'stac': 120224,
#  'technologies': 124195,
#  'owners': 99911,
#  'boards': 28966,
#  'technology': 124196,
#  'writing': 135521,
#  'lost': 72623,
#  'wrong': 135531,
#  'being': 27343,
#  'whether': 134127,
#  'fault': 50903,
#  'something': 118814,
#  'else': 47604,
#  'however': 60867,
#  'decompress': 41743,
#  'troubled': 127503,
#  'recompress': 109149,
#  'without': 134909,
#  'usually': 130407,
#  'reappears': 108836,
#  'above': 19288,
#  'mentioned': 82972,
#  'freeware': 53255,
#  'expansion': 49836,
#  'utility': 130455,
#  'dd': 41439,
#  'expand': 49823,
#  'boardcompressed': 28959,
#  'unless': 129523,
#  'installed': 63856,
#  'product': 105515,
#  'now': 97076,
#  'unlikely': 129528,
#  'holes': 60291,
#  'autodoublerdiskdoubler': 25398,
#  'related': 109809,
#  'fixed': 51929,
#  'sad': 113311,
#  'very': 131660,
#  'reluctant': 109941,
#  'buy': 31019,
#  'stacs': 120242,
#  'theyre': 125164,
#  'stinky': 121026,
#  'hey': 59523,
#  'thats': 124899,
#  'competition': 36783,
#  'computing': 37099,
#  'communications': 36622,
#  'services': 115855,
#  'office': 98068,
#  'illinoisurbana': 62315,
#  'phone': 102534,
#  '2173335217': 9459,
#  'stankerruiucedu': 120379,
#  'irwincmptrclonestarorg': 64807,
#  'irwin': 64806,
#  'arnstein': 24169,
#  'recommendation': 109137,
#  'duc': 45974,
#  'expires': 49917,
#  'sat': 113853,
#  '1993': 6325,
#  '050000': 1067,
#  'gmt': 55826,
#  'computrac': 37101,
#  'inc': 62825,
#  'richardson': 111221,
#  'tx': 128194,
#  'ducati': 45977,
#  'gts': 57228,
#  '13': 3767,
#  '900gts': 17713,
#  '1978': 6217,
#  '17k': 5519,
#  'runs': 112877,
#  'paint': 100306,
#  'bronzebrownorange': 30199,
#  'faded': 50468,
#  'leaks': 70664,
#  'oil': 98214,
#  'pops': 104034,
#  '1st': 8802,
#  'accel': 19462,
#  'shop': 116734,
#  'trans': 126941,
#  'leak': 70659,
#  'sold': 118683,
#  'bike': 28077,
#  'owner': 99906,
#  'want': 133049,
#  '3495': 11701,
#  'thinking': 125232,
#  '3k': 12338,
#  'stable': 120220,
#  'mate': 79098,
#  'beemer': 27213,
#  'jap': 65585,
#  'myself': 93841,
#  'axis': 25705,
#  'motors': 88790,
#  'tuba': 127766,
#  'honk': 60518,
#  'therefore': 125072,
#  'computracrichardsontx': 37102,
#  'dod': 44756,
#  '0826': 1426,
#  'r756': 107734,
#  'davidterminusericssonse': 41229,
#  'david': 41168,
#  'bold': 29134,
#  'popular': 104038,
#  'morality': 88448,
#  'camtec': 32362,
#  'electronics': 47408,
#  'ericsson': 48755,
#  'leicester': 70937,
#  'england': 48194,
#  '77': 16433,
#  'bangkok': 26378,
#  '17570freenetcarletonca': 5450,
#  'ad354freenetcarletonca': 19917,
#  'james': 65500,
#  'owens': 99896,
#  'previous': 105102,
#  'rude': 112741,
#  'youve': 137997,
#  'hold': 60270,
#  'end': 48036,
#  'different': 43431,
#  'stick': 120961,
#  'look': 72490,
#  'posting': 104255,
#  'again': 20607,
#  'intent': 64042,
#  'explaining': 49925,
#  'jung': 67146,
#  'moral': 88442,
#  'god': 55921,
#  'overlooked': 99745,
#  'main': 77939,
#  'seem': 115200,
#  'saying': 113999,
#  'unknowable': 129507,
#  'his': 59914,
#  'yep': 137722,
#  'jew': 66054,
#  'jewish': 66060,
#  'jews': 66069,
#  'covenant': 38821,
#  'between': 27825,
#  'yhwh': 137786,
#  'patriarchs': 101070,
#  'abraham': 19298,
#  'moses': 88621,
#  'case': 32951,
#  'establishes': 49045,
#  'follow': 52475,
#  'mankind': 78379,
#  'decide': 41665,
#  'boundaries': 29551,
#  'fall': 50588,
#  'sadducees': 113328,
#  'believed': 27406,
#  'torah': 126512,
#  'required': 110394,
#  'whereas': 134110,
#  'pharisees': 102353,
#  'ancestors': 22326,
#  'judaism': 67016,
#  'interpretation': 64251,
#  'lead': 70625,
#  'nuances': 97285,
#  'talmud': 123670,
#  'essence': 49026,
#  'biblical': 27964,
#  'man': 78251,
#  'christian': 34741,
#  'necessarily': 94909,
#  'indicate': 63064,
#  'anything': 23042,
#  'outside': 99616,
#  'relationship': 109818,
#  'speculate': 119397,
#  'comes': 36428,
#  'mind': 85219,
#  'created': 39162,
#  'image': 62370,
#  'committed': 36568,
#  'live': 72024,
#  'christs': 34792,
#  'example': 49550,
#  'pressed': 105006,
#  'argue': 23957,
#  'kind': 68567,
#  'trouble': 127501,
#  'come': 36420,
#  'conclusion': 37210,
#  'upsets': 130001,
#  'cart': 32890,
#  'wants': 133061,
#  ...}

# %% [markdown]
# Portanto, o documento abaixo...

# %%
X[0]
# Out:
# 'from lerxstwamumdedu wheres my thing subject what car is this nntppostinghost rac3wamumdedu organization university of maryland college park lines 15  i was wondering if anyone out there could enlighten me on this car i saw the other day it was a 2door sports car looked to be from the late 60s early 70s it was called a bricklin the doors were really small in addition the front bumper was separate from the rest of the body this is all i know if anyone can tellme a model name engine specs years of production where this car is made history or whatever info you have on this funky looking car please email  thanks  il  brought to you by your neighborhood lerxst      '

# %% [markdown]
# ... é transformado no seguinte vetor:

# %%
X_vec[0]
# Out:
# <1x138727 sparse matrix of type '<class 'numpy.int64'>'
# 	with 86 stored elements in Compressed Sparse Row format>

# %%
from scipy.sparse import find

_, word_num, word_count = find(X_vec[0])

for w, c in sorted(zip(word_num, word_count), key=lambda x: x[1], reverse=True):
    print('palavra #{} aparece {} vezes'.format(w, c))
# Out:
# palavra #124909 aparece 6 vezes
# palavra #32625 aparece 5 vezes
# palavra #125281 aparece 5 vezes
# palavra #133183 aparece 4 vezes
# palavra #53426 aparece 3 vezes
# palavra #64814 aparece 3 vezes
# palavra #98012 aparece 3 vezes
# palavra #23034 aparece 2 vezes
# palavra #62053 aparece 2 vezes
# palavra #65079 aparece 2 vezes
# palavra #98480 aparece 2 vezes
# palavra #126160 aparece 2 vezes
# palavra #137927 aparece 2 vezes
# palavra #4594 aparece 1 vezes
# palavra #10785 aparece 1 vezes
# palavra #14878 aparece 1 vezes
# palavra #15920 aparece 1 vezes
# palavra #20024 aparece 1 vezes
# palavra #21397 aparece 1 vezes
# palavra #27020 aparece 1 vezes
# palavra #29058 aparece 1 vezes
# palavra #30021 aparece 1 vezes
# palavra #30245 aparece 1 vezes
# palavra #30728 aparece 1 vezes
# palavra #31096 aparece 1 vezes
# palavra #32215 aparece 1 vezes
# palavra #32365 aparece 1 vezes
# palavra #36225 aparece 1 vezes
# palavra #38649 aparece 1 vezes
# palavra #41266 aparece 1 vezes
# palavra #45058 aparece 1 vezes
# palavra #46499 aparece 1 vezes
# palavra #47663 aparece 1 vezes
# palavra #48176 aparece 1 vezes
# palavra #48253 aparece 1 vezes
# palavra #53439 aparece 1 vezes
# palavra #53904 aparece 1 vezes
# palavra #58656 aparece 1 vezes
# palavra #59952 aparece 1 vezes
# palavra #62259 aparece 1 vezes
# palavra #62770 aparece 1 vezes
# palavra #63343 aparece 1 vezes
# palavra #68998 aparece 1 vezes
# palavra #70317 aparece 1 vezes
# palavra #71089 aparece 1 vezes
# palavra #71090 aparece 1 vezes
# palavra #71758 aparece 1 vezes
# palavra #72493 aparece 1 vezes
# palavra #72498 aparece 1 vezes
# palavra #77630 aparece 1 vezes
# palavra #78932 aparece 1 vezes
# palavra #82319 aparece 1 vezes
# palavra #87830 aparece 1 vezes
# palavra #93613 aparece 1 vezes
# palavra #94398 aparece 1 vezes
# palavra #95036 aparece 1 vezes
# palavra #96170 aparece 1 vezes
# palavra #98969 aparece 1 vezes
# palavra #99096 aparece 1 vezes
# palavra #99366 aparece 1 vezes
# palavra #99456 aparece 1 vezes
# palavra #100723 aparece 1 vezes
# palavra #103399 aparece 1 vezes
# palavra #105517 aparece 1 vezes
# palavra #107784 aparece 1 vezes
# palavra #108803 aparece 1 vezes
# palavra #110659 aparece 1 vezes
# palavra #113975 aparece 1 vezes
# palavra #115677 aparece 1 vezes
# palavra #118105 aparece 1 vezes
# palavra #119366 aparece 1 vezes
# palavra #119741 aparece 1 vezes
# palavra #121733 aparece 1 vezes
# palavra #124407 aparece 1 vezes
# palavra #124868 aparece 1 vezes
# palavra #125062 aparece 1 vezes
# palavra #125208 aparece 1 vezes
# palavra #129438 aparece 1 vezes
# palavra #133850 aparece 1 vezes
# palavra #134046 aparece 1 vezes
# palavra #134053 aparece 1 vezes
# palavra #134108 aparece 1 vezes
# palavra #134119 aparece 1 vezes
# palavra #135127 aparece 1 vezes
# palavra #137661 aparece 1 vezes
# palavra #137969 aparece 1 vezes

# %%
cw = [(vectorizer.vocabulary_[w] if w in vectorizer.vocabulary_ else -1, w) for w in X[0].split()]

for c, w in sorted(cw):
    if c != -1:
        print('{}: {}'.format(w, c))
    else:
        print('{}: huh?'.format(w))
# Out:
# a: huh?
# a: huh?
# a: huh?
# i: huh?
# i: huh?
# i: huh?
# 15: 4594
# 2door: 10785
# 60s: 14878
# 70s: 15920
# addition: 20024
# all: 21397
# anyone: 23034
# anyone: 23034
# be: 27020
# body: 29058
# bricklin: 30021
# brought: 30245
# bumper: 30728
# by: 31096
# called: 32215
# can: 32365
# car: 32625
# car: 32625
# car: 32625
# car: 32625
# car: 32625
# college: 36225
# could: 38649
# day: 41266
# doors: 45058
# early: 46499
# email: 47663
# engine: 48176
# enlighten: 48253
# from: 53426
# from: 53426
# from: 53426
# front: 53439
# funky: 53904
# have: 58656
# history: 59952
# if: 62053
# if: 62053
# il: 62259
# in: 62770
# info: 63343
# is: 64814
# is: 64814
# is: 64814
# it: 65079
# it: 65079
# know: 68998
# late: 70317
# lerxst: 71089
# lerxstwamumdedu: 71090
# lines: 71758
# looked: 72493
# looking: 72498
# made: 77630
# maryland: 78932
# me: 82319
# model: 87830
# my: 93613
# name: 94398
# neighborhood: 95036
# nntppostinghost: 96170
# of: 98012
# of: 98012
# of: 98012
# on: 98480
# on: 98480
# or: 98969
# organization: 99096
# other: 99366
# out: 99456
# park: 100723
# please: 103399
# production: 105517
# rac3wamumdedu: 107784
# really: 108803
# rest: 110659
# saw: 113975
# separate: 115677
# small: 118105
# specs: 119366
# sports: 119741
# subject: 121733
# tellme: 124407
# thanks: 124868
# the: 124909
# the: 124909
# the: 124909
# the: 124909
# the: 124909
# the: 124909
# there: 125062
# thing: 125208
# this: 125281
# this: 125281
# this: 125281
# this: 125281
# this: 125281
# to: 126160
# to: 126160
# university: 129438
# was: 133183
# was: 133183
# was: 133183
# was: 133183
# were: 133850
# what: 134046
# whatever: 134053
# where: 134108
# wheres: 134119
# wondering: 135127
# years: 137661
# you: 137927
# you: 137927
# your: 137969

# %% [markdown]
# Agora podemos usar **qualquer classificador** para determinar o newsgroup de um documento a partir de seu conteudo. Vamos testar o classificador ``MultinomialNB``:

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_predict
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('vec', CountVectorizer()),
    ('clf', MultinomialNB())
])

y_pred = cross_val_predict(pipeline, X, y=y, cv=3, n_jobs=-1, verbose=1)
accuracy = accuracy_score(data.target, y_pred)
print(accuracy)
# Out:
# 0.8248188085557716
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.5s finished

# %% [markdown]
# **Atividade:**
#
# O que são:
# - stemming
# - TF-IDF
# - Laplacian smoothing
# - n-gramas
# - análise de sentimento

# %% [markdown]
# **R:**
#   - Stemming (ou stemização) é o nome dado ao processo de reduzir uma palavra ao seu "tronco" (stem) ou raíz, por exemplo, as palavras "gatos, gatinhos e gatão" iriam todas para a raíz "gato"
#   - O TFIDF (term frequency–inverse document frequency) busca refletir em termo de importância o valor de cada palavra em uma frase ou contexto. A ideia consiste em aumentar proporcionalmente conforme o número de aparições da mesma em um dado texto.
#   - Laplacian Smoothing é um sistema para "amenizar vértices". Em modelos naive-bayes, isso serve para amenizar os eveitos contrários de encontrar uma palavra não conhecida em uma frase. Dessa forma, quando os valores forem multiplicados, a probabilidade desta palavra não conhecida não será zero e, portanto, a probabilidade da frase em geral será diferente de zero (dando valor às palavras conhecidas na frase).
#   - Um n-grama é uma sequência de caractéres conhecidos e restritos à um dado conjunto, usado, por exemplo, para o estudo de cadeias genéticas (ATGC).
#   - Análise de sentimento é um modelo de classificação textual que busca classificar as frases entre positivas e negativas, podendo também dar um grau de "neutralidade" da mesma.

# %% [markdown]
# **Atividade:**
#
# - Explore os hiperparâmetros do vectorizer e do classificador para melhorar a acurácia do sistema. Um simples parâmetro de regularização no MultinomialNB pode facilmente elevar a acurácia para quase 90%!
# - Teste também um vectorizer do tipo ``TfidfVectorizer``
# - Teste também um classificador que não seja naive-Bayes. SVMs costumam ser populares neste meio.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfid_clf = Pipeline([
    ('vec', TfidfVectorizer()),
    ('clf', MultinomialNB())
])

y_pred = cross_val_predict(tfid_clf, X, y=y, cv=3, 
                           n_jobs=-1, verbose=1)
accuracy = accuracy_score(data.target, y_pred)
print(accuracy)
# Out:
# 0.8283542513699841
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.8s finished

# %%
from sklearn.model_selection import GridSearchCV
print('im working')

gscv = GridSearchCV(pipeline, {
#     'vec__ngram_range': [(1, 1), (1, 2), (1, 3)],
    'clf__alpha': [.3, .5, .7, 1]
})

gscv.fit(X, y)

accuracy = accuracy_score(gscv.predict(X), y_pred)
print(accuracy)
# Out:
# im working
# /Users/gil/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /Users/gil/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /Users/gil/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:472: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
